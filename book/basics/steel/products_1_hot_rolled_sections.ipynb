# %% [markdown]
# # Products 1: hot-rolled sections
#
# ## I-sections
# ```{figure} Images/ipe_inp_sections.png
# ---
# align: left
# ---
# IPE and INP sections
# ```
# ```{figure} Images/connection_beams_endplate.png
# ---
# align: right
# ---
# Connection between two beams by means of an endplate.
# ```
# ```{figure} Images/connection_beamcolumn_elongated_endplate.png
# ---
# align: left
# ---
# Connection between beam (I-section) and column (H-section) by means of an elongated endplate.
# ```
#
# | Type | Size | $h$ (mm) | $b$ (mm) | $M_{y;el;d}$ S235 (kNm) | $M_{y;el;d}$ S355 (kNm) |
# |------|------|--------|--------|---------------------|---------------------|
# | IPE  | 80 - 600 | 80 - 600 | 42 - 300 | 4,56 - 1076 | 6,89 - 1627 |
# | INP  | 80 - 750 | 80 - 750 | 46 - 263 | 4,71 - 1467 | 7,71 - 2216 |
#
# Applications: Light structures in residential and non-residential buildings. Used a lot in industrial buildings. It is also possible to use the I sections to make castellated beams.
#
# ## H-sections
# ```{figure} Images/hea_heb_hem_sections.png
# ---
# align: left
# ---
# HE-A, HE-B,HE-M sections, for each
# series the interior dimensions correspond.
# ```
# ```{figure} Images/connection_hebeam_ipebeam_hecolumn.png
# ---
# align: right
# ---
# Connection between HE-beam and IPE-beam
# on a HE-column.
# ```
# ```{figure} Images/hea_column_support.png
# ---
# align: left
# ---
# HE-A column support
# ```
#
# | Type | Size | $h$ (mm) | $b$ (mm) | $M_{z;el;d}$ S235 (kNm) | $M_{z;el;d}$ S355 (kNm) |
# |------|------|--------|--------|--------------------|--------------------|
# | HE A | 100 - 1000 | 96 - 990 | 100 - 300 | 17,1 - 2629 | 25,8 - 3972 |
# | HE B | 100 - 1000 | 100 - 1000 | 100 - 300 | 21,1 - 3030 | 31,9 – 4578 |
# | HE M | 100 - 1000 | 120 – 1008 | 106 - 302 | 44,8 - 3368 | 67,6 – 5088 |
#
#
# Applications: H-sections are useful for compression elements (columns) or beams where the structural height has to be limited. The increase in section modulus is achieved by using thicker flanges. Due to their large width the H-sections retain their shape relatively well.
#
# ## U-sections
# ```{figure} Images/uap_unp_sections.png
# ---
# align: left
# ---
# UAP and UNP sections
# ```
#
# | Type | Size | $h$ (mm) | $b$ (mm) | $M_{z;el;d}$ S235 (kNm) | $M_{z;el;d}$ S355 (kNm) |
# |------|------|--------|--------|--------------------|--------------------|
# | UAP  | 80 - 400 | 80 - 400 | 45 - 100 | 6,29 - 128 | 9,51 - 193 |
# | UNP  | 80 - 400 | 80 - 400 | 45 - 100 | 6,22 - 239 | 9,4 - 361 |
#
#
# Applications: Floor edges and landings. Connections between UNP-sections can be complicated due to the inclined edges.U-profiles are not symmetrical, causing the sections to bend along both axes when loaded vertically.
#
# ## Hollow sections
# ```{figure} Images/chs_rhs.png
# ---
# align: left
# ---
# CHS (circular hollow section) and
# RHS (rectangular hollow section)
# ```
# ```{figure} Images/space_frame_node.png
# ---
# align: right
# ---
# Space frame node, made
# from hollow sections.
# ```
# ```{figure} Images/truss_rectangular_hollow_sections.png
# ---
# align: left
# ---
# Truss made of rectangular hollow sections. The bridge lies between the
# trusses rather than on top of them.
# ```
#
# | Type | Size | $h$ (mm) | $t$ (mm) |
# |------|------|--------|--------|
# | CHS  | 42,4 - 610 | 42,4 - 610 | 2,6 - 30 |
# | RHS  | 40 - 400 | 40 - 400 | 3 - 16 |
#
#
# Application: (3D)trusses, columns.
#
# ## Sheet piling
# ```{figure} Images/sheet_piles.png
# ---
# align: left
# ---
# Different sheet piling sections (U and Z sections)
# ```
#
# Applications: Basement walls, foundations, and hydraulic engineering. Sheet piles are available in different sizes and lengths. Sheet piles are used as walls in building pits and structres below ground level. Vertical loads can also be taken.
