# %% [markdown]
# # Kolommen
#
# Uitgangspunten: kolom gelamineerd hout GL24h, stramien 6 m x 6 m, houten vloer $G = 2.0 kN/m^2$ en CC2
#
# | Q = 2 kN/m², max 3 bouwlagen | Q = 2 kN/m², max 5 bouwlagen |Q = 5 kN/m², max 3 bouwlagen |
# |-----------------------|-----------------------|-----------------------|
# | Q = 2 kN/m²           |Q = 2 kN/m²           |Q = 5 kN/m²           |
# | $P_{d}$ = 5.4 kN/m²   | $P_{d}$ = 5.4 kN/m²   | $P_{d}$ = 9.9 kN/m²   |
# | n = 2 verdiepingen    | n = 4 verdiepingen    | n = 2 verdiepingen    |
# | $F_{Gk}$ = 144 kN     | $F_{Gk}$ = 288 kN     | $F_{Gk}$ = 144 kN     |
# | $F_{Qk}$ = 144 kN     | $F_{Qk}$ = 288 kN     | $F_{Qk}$ = 360 kN     |

# %%
import numpy as np
import matplotlib.pyplot as plt

L_buc23 = [2.5, 3.5, 5, 6.5]
hb_23 = [169, 186, 216, 244]

L_buc25 = [2.5, 3.5, 5, 6.5]
hb_25 = [230, 238, 264, 294]

L_buc53 = [2.5, 3.5, 5, 6.5]
hb_53 = [221, 230, 257, 287]

plt.figure()
plt.title('Houten kolom')
plt.plot(L_buc23, hb_23, c= 'b', label='Q = 2 kN /m^2, max 3 bouwlagen')
plt.plot(L_buc25, hb_25, c= 'g', label='Q = 2 kN /m^2, max 5 bouwlagen')
plt.plot(L_buc53, hb_53, c= 'r', label='Q = 5 kN /m^2, max 3 bouwlagen')
plt.xlabel('Kniklengte [m]')
plt.ylabel('h=b [mm]')
plt.legend(loc='best');
