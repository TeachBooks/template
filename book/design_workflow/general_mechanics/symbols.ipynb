# %% [markdown]
# # Symbols, quantities and units

# %% [markdown]
# | Symbol | Name                                | Symbol |
# |--------|-------------------------------------|--------|
# | qy     | Distributed load in y direction    | N/m    |
# | qz     | Distributed load in z direction    | N/m    |
# | s      | Distributed shear force            | N/m    |
# | t      | Thickness                           | m      |
# | tf     | Flange thickness                   | m      |
# | tw     | Web thickness                      | m      |
# | yC     | Y-coordinate of the center of gravity | m    |
# | zC     | Z-coordinate of the center of gravity | m    |
# | yNC    | Y-coordinate of the center of axial force | m |
# | zNC    | Z-coordinate of the center of axial force | m |
# | I      | Second moment of area              | m^4    |
# | i      | Radius of gyration                 | m      |
# | W      | Section modulus                    | m^3    |
# | α      | Thermal expansion coefficient      | K^-1   |
# | ε      | Strain                              | -      |
# | εt     | Breaking strain (tension)          | -      |
# | εu     | Ultimate strain                     | -      |
# | εy     | Yield strain                        | -      |
# | κ      | Curvature                           | m^-1   |
# | γ      | Load factor                        | -      |
# | γ      | Shear strain                        | rad    |
# | γG     | Load factor for permanent loads    | -      |
# | γQ     | Load factor for variable loads     | -      |
# | θ      | Angle of rotation                   | rad    |
# | σ      | Normal stress                       | N/m^2  |
# | τ      | Shear stress                        | N/m^2  |
