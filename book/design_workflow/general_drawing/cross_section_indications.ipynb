# %% [markdown]
# # Cross section indications
#
# For each material, a different hatch is used. Furthermore, the type of hatch can differ as the scale of the drawing
# changes. This is done to make sure that at higher scales the hatches are not too complicated, as the areas to
# hatch on the drawing decrease rapidly with increasing scale. In the tables below two markings appear:
#
# :black_circle: = Scale at which the hatch needs to be used
# :white_circle: = Scale at which the hatch needs to be used with the material added in text
#
# The tables are based on the Dutch code NEN 47.
#
# ## Stone-like materials
#
# | No. | Description                           | Hatch                                           | Scale        |              |              |              |              |              |Remarks       |
# | --- | -----------------------               | -----                                           | -----        | -----        | ----         | ----         | ----         | ----         | ---          |
# |     |                                       |                                                 | 1:100        |1:50          |1:20          |1:10          |1:5           |1:1           |              |
# | 1   | Brick masonry                         |```{figure} Images/Brick 1.png```                |:black_circle:|:black_circle:|              |              |              |              |              |
# |     |                                       |```{figure} Images/Brick 2.png```                |              |:black_circle:|:black_circle:|:black_circle:|:black_circle:|:black_circle:|              |
# |     |                                       |```{figure} Images/Brick 3.png```                |              |:black_circle:|:black_circle:|:black_circle:|:black_circle:|:black_circle:|              |
# | 2   | Stone-like materials                  |```{figure} Images/Stone-like.png```             |:white_circle:|       |      |        |       |       |e.g. fireproof material, roof tiles |
# | 3   | Non-brick masonry                     |```{figure} Images/Non-brick.png```              |              |       |      |        |       |       |e.g. concrete masonry units    |
# | 4   | Non load carrying division walls      |```{figure} Images/Non-load.png```               |              |       |      |        |       |       |                          |
# |     |                                       |```{figure} Images/Non-load 2.png```             |              |       |      |        |       |       |                          |
# |     |                                       |```{figure} Images/Non-load 3.png```             |              |       |      |        |       |       |                          |
# | 5   | Reinforced concrete (cast in situ)    |```{figure} Images/Reinforced concrete.png```    |              |       |      |        |       |       |                          |
# |     |                                       |```{figure} Images/Reinforced concrete 2.png```  |              |       |      |        |       |       |                          |
# | 6   | Reinforced concrete (precast)         |```{figure} Images/Reinforced concrete precast.png```|   |       |      |        |       |       |                          |
# | 7   | Plain concrete                        |```{figure} Images/Plain concrete.png```         |       |       |      |        |       |       |e.g. lightweight concrete |
# | 8   | Decorative concrete                   |```{figure} Images/Decorative concrete.png```    |       |       |      |        |       |       |                          |
# | 9   | Natural stone                         |```{figure} Images/Natural stone.png```          |       |       |      |        |       |       |                          |
# | 10  | Single floor/wall finishing           |```{figure} Images/Single floor wall.png```      |       |       |      |        |       |       | e.g. plaster     |
# | 11  | Composite floor/wall finishing        |```{figure} Images/Composite.png```              |       |       |      |        |       |       |                          |

# %% [markdown]
# ## Timber materials

# %% [markdown]
# |No.| Description                        | Hatch                                | Scale        |              |              |              |              |              |Remarks       |
# |---| -----------------------            | -----                                | -----        | -----        | ----         | ----         | ----         | ----         | ---          |
# |   |                                    |                                      | 1:100        |1:50          |1:20          |1:10          |1:5           |1:1           |              |
# |12 | Softwood                           |```{figure} Images/Softwood.png```     |       |       |      |        |       |       |                          |
# |13 | Hardwood                           |```{figure} Images/Hardwood.png```      |       |       |      |        |       |       |                          |
# |14 | Softwood/Hardwood (along the grain)|```{figure} Images/Soft-Hardwood along the grain.png```       |       |       |      |        |       |       |                          |
# |15 | Glued seam                         |```{figure} Images/Glued seam.png```    |       |       |      |        |       |       |                          |
# |16 | Cladding panel                     |```{figure} Images/Cladding panel.png```     |       |       |      |        |       |       |                          |
# |17 | Isolation panel                    |```{figure} Images/Isolation panel.png```    |       |       |      |        |       |       |                          |

# %% [markdown]
# ## Metals

# %% [markdown]
# | No. | Description                   | Hatch                           | Scale |              |              |              |              |              |Remarks       |
# | --- | -----------------------       | -----                           | ----- | -----        | ----         | ----         | ----         | ----         | ---          |
# |     |                               |                                 | 1:100 |1:50          |1:20          |1:10          |1:5           |1:1           |              |
# | 18  | Steel                         |```{figure} Images/Steel.png```|       |       |      |        |       |       |                          |
# | 19  | Aluminium, brass, copper etc. |```{figure} Images/Aluminium.png```|       |       |      |        |       |       |                          |
# | 20  | Lead                          |```{figure} Images/Lead.png```|       |       |      |        |       |       |                          |
# | 21  | Zinc                          |```{figure} Images/Zinc.png```|       |       |      |        |       |       |                          |

# %% [markdown]
# ## Miscellaneous

# %% [markdown]
# | No. | Description    | Hatch                                 | Scale |       |      |              |              |              |Remarks       |
# | --- | -------------- | -----                                 | ----- | ----- | ---- | ----         | ----         | ----         | ---          |
# |     |                |                                       | 1:100 |1:50   |1:20  |1:10          |1:5           |1:1           |              |
# | 22  | Synthetics     |```{figure} Images/Synthetics.png```   |       |       |      |        |       |       |                          |
# | 23  | Sealant        |```{figure} Images/Sealant.png```      |       |       |      |        |       |       |                          |
# | 24  | Foil, bitumen  |```{figure} Images/Foil.png```         |       |       |      |        |       |       |                          |
# | 25  | Ground level   |```{figure} Images/Gorund level.png``` |       |       |      |        |       |       |                          |
# | 26  | Sand           |```{figure} Images/Sand.png```         |       |       |      |        |       |       |                          |
# | 27  | Gravel         |```{figure} Images/Gravel.png```       |       |       |      |        |       |       |                          |
# | 28  | Water          |```{figure} Images/Water.png```        |       |       |      |        |       |       |                          |
# | 29  | Glass          |```{figure} Images/Glass.png```        |       |       |      |        |       |       |                          |
