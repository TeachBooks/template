# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams.update({'font.size': 16})
# TUDelft colors palette
colors = ["#0C2340","#00B8C8","#0076C2","#6F1D77","#EF60A3","#A50034","#E03C31","#EC6842","#FFB81C","#6CC24A","#009B77"]

# %% [markdown]
# ## **Template #1**

# %%
# -----------------------------------------------------------------
plot_title                  = "this is the title"
font                        = "Arial"
x_label                     = "xlabel [$x-units$]"
y_label                     = "ylabel [$y-units$]"
legend                      = False
grid                        = False
save_svg                    = True
remove_ticks                = True
remove_ticks_labels         = True
file_name                   = "template_blank"
# -----------------------------------------------------------------

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot() # axes_class=AxesZero)
ax.set_title(plot_title, fontfamily=font)

ax.set_xlabel(x_label, fontfamily=font)
ax.set_ylabel(y_label, fontfamily=font)

plt.setp(ax.spines.values(), linewidth=2)
ax.spines["left"].set_position(("data", 0))
ax.spines["bottom"].set_position(("data", 0))
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

ax.tick_params(axis='x', labelsize=13, width=2, length=8)
ax.tick_params(axis='y', labelsize=13, width=2, length=8)

if grid: ax.grid()
if legend: ax.legend(prop={"family":font})
if remove_ticks: ax.set_xticks([]); ax.set_yticks([])
if remove_ticks_labels: ax.set_xticklabels([]); ax.set_yticklabels([])
if save_svg: plt.savefig(file_name + '.svg')

# %%
# -----------------------------------------------------------------
plot_title                  = ""
font                        = "Arial"
x_label                     = "Year"
y_label                     = "Normalized Present Value [$-$]"
legend                      = True
grid                        = False
save_svg                    = True
remove_ticks                = False
remove_ticks_labels         = False
file_name                   = "template_exp_decay"
# -----------------------------------------------------------------

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot() # axes_class=AxesZero)
ax.set_title(plot_title, fontfamily=font)
ax.set_xlabel(x_label, fontfamily=font)
ax.set_ylabel(y_label, fontfamily=font)

plt.setp(ax.spines.values(), linewidth=2)
ax.spines["left"].set_position(("data", 0))
ax.spines["bottom"].set_position(("data", 0))
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

t = np.linspace(0,101)
y_2 = 1 / (1 + 0.02)**t
y_4 = 1 / (1 + 0.04)**t

# plotting
ax.plot(t, y_2, label='2%', color=colors[0], linewidth=4)
ax.plot(t, y_4, label='4%', color=colors[1], linewidth=4)
ax.plot(1, 0, ">k", transform=ax.get_yaxis_transform(), clip_on=False)
ax.plot(0, 1, "^k", transform=ax.get_xaxis_transform(), clip_on=False)

# not a permanent solution (removed the part below 0)
# ---> find a better way to auto set upper bound
ax.spines.bottom.set_bounds(0, 105)
ax.spines.left.set_bounds(0, 1.05)

ax.tick_params(axis='x', labelsize=13, width=2, length=8)
ax.tick_params(axis='y', labelsize=13, width=2, length=8)

if grid: ax.grid()
if legend: ax.legend(prop={"family":font})
if remove_ticks: ax.set_xticks([]); ax.set_yticks([])
if remove_ticks_labels: ax.set_xticklabels([]); ax.set_yticklabels([])
if save_svg: plt.savefig(file_name + '.svg')

# %% [markdown]
# ## **Template #3**

# %%
# -----------------------------------------------------------------
plot_title                  = "Cumulative distribution function, $F_{N}(n) = P(N \leq n)$"
font                        = "Arial"
x_label                     = "Fatalities [$-$]"
y_label                     = "Probability [$-$]"
legend                      = False
grid                        = False
save_svg                    = True
remove_ticks                = False
remove_ticks_labels         = False
file_name                   = "template_cdf"
# -----------------------------------------------------------------

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot() # axes_class=AxesZero)
plt.setp(ax.spines.values(), linewidth=2.0)

ax.set_title(plot_title, fontfamily=font, x=0.55, y=1.0)
ax.set_xlabel(x_label, fontfamily=font)
ax.set_ylabel(y_label, fontfamily=font)

# data
N_fatalities = ['0', '10', '100', '']
N_fatalities_loc = [0.03, 0.33, 0.76, 0.95]
pdf = ['0', '0.989', '0.999', '1']
pdf_loc = [0.03, 0.66, 0.86, 0.99]

# plotting
ax.step(N_fatalities_loc, pdf_loc, color=colors[0], linewidth=4)

# ticks
ax.set_xticks(N_fatalities_loc)
ax.set_xticklabels(N_fatalities)
ax.set_yticks(pdf_loc)
ax.set_yticklabels(pdf)
ax.tick_params(axis='x', labelsize=13, width=2, length=8)
ax.tick_params(axis='y', labelsize=13, width=2, length=8)

# add text
ax.text(0.8, 0.9, r'} $10^{-3}$', fontsize=16, fontfamily=font)
ax.text(0.37, 0.725, r'} $10^{-2}$', fontsize=16, fontfamily=font)

current_values = plt.gca().get_yticks()
plt.gca().set_yticklabels(['{:,.3f}'.format(x) for x in current_values])

if grid: ax.grid()
if legend: ax.legend(prop={"family":font})
if remove_ticks: ax.set_xticks([]); ax.set_yticks([])
if remove_ticks_labels: ax.set_xticklabels([]); ax.set_yticklabels([])
if save_svg: plt.savefig(file_name + '.svg')
